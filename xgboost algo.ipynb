# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\nisha\Downloads\train_dataset.csv");
df.head()
# Out:
#      ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0  7135    1654     CL  D-penicillamine  19581   F       N            N
# 1  7326      41      C  D-penicillamine  22880   F     NaN            N
# 2  7254     297      D              NaN  27957   F       N            N
# 3  3135    1872      C  D-penicillamine  21111   F     NaN            Y
# 4  2483     939     CL  D-penicillamine  18061   F     NaN          NaN
#
#   Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0       Y     N        0.3        279.0     2.96    84.0    1500.8   99.43
# 1     NaN     N        0.3          NaN     2.96     NaN    1835.4   26.35
# 2     NaN     N        0.3        328.0     2.64     4.0       NaN     NaN
# 3       Y     N        0.3        302.0     2.02    49.0       NaN   26.35
# 4     NaN     N        0.5        344.0     3.11    91.0       NaN  104.56
#
#    Tryglicerides  Platelets  Prothrombin  Stage
# ...

# %%
df = df.drop(['ID','N_Days','Status','Drug'],axis = 1)

# %%
df.head()
# Out:
#      Age Sex Ascites Hepatomegaly Spiders Edema  Bilirubin  Cholesterol  \
# 0  19581   F       N            N       Y     N        0.3        279.0
# 1  22880   F     NaN            N     NaN     N        0.3          NaN
# 2  27957   F       N            N     NaN     N        0.3        328.0
# 3  21111   F     NaN            Y       Y     N        0.3        302.0
# 4  18061   F     NaN          NaN     NaN     N        0.5        344.0
#
#    Albumin  Copper  Alk_Phos    SGOT  Tryglicerides  Platelets  Prothrombin  \
# 0     2.96    84.0    1500.8   99.43          109.0      293.0         10.2
# 1     2.96     NaN    1835.4   26.35          131.0      308.0         10.8
# 2     2.64     4.0       NaN     NaN          116.0      194.0         10.3
# 3     2.02    49.0       NaN   26.35            NaN        NaN         10.5
# 4     3.11    91.0       NaN  104.56            NaN      306.0         11.4
#
#    Stage
# 0    4.0
# 1    1.0
# 2    3.0
# 3    4.0
# 4    2.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6800 entries, 0 to 6799
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            6800 non-null   int64
#  1   Sex            6800 non-null   object
#  2   Ascites        4554 non-null   object
#  3   Hepatomegaly   4373 non-null   object
#  4   Spiders        4210 non-null   object
#  5   Edema          6800 non-null   object
#  6   Bilirubin      6800 non-null   float64
#  7   Cholesterol    3699 non-null   float64
#  8   Albumin        6800 non-null   float64
#  9   Copper         4644 non-null   float64
#  10  Alk_Phos       4302 non-null   float64
#  11  SGOT           4698 non-null   float64
#  12  Tryglicerides  3988 non-null   float64
#  13  Platelets      6462 non-null   float64
#  14  Prothrombin    6645 non-null   float64
#  15  Stage          6800 non-null   float64
# dtypes: float64(10), int64(1), object(5)
# memory usage: 850.1+ KB

# %%
df['Ascites'].fillna('N',inplace = True)

# %%
df.head()
# Out:
#      Age Sex Ascites Hepatomegaly Spiders Edema  Bilirubin  Cholesterol  \
# 0  19581   F       N            N       Y     N        0.3        279.0
# 1  22880   F       N            N     NaN     N        0.3          NaN
# 2  27957   F       N            N     NaN     N        0.3        328.0
# 3  21111   F       N            Y       Y     N        0.3        302.0
# 4  18061   F       N          NaN     NaN     N        0.5        344.0
#
#    Albumin  Copper  Alk_Phos    SGOT  Tryglicerides  Platelets  Prothrombin  \
# 0     2.96    84.0    1500.8   99.43          109.0      293.0         10.2
# 1     2.96     NaN    1835.4   26.35          131.0      308.0         10.8
# 2     2.64     4.0       NaN     NaN          116.0      194.0         10.3
# 3     2.02    49.0       NaN   26.35            NaN        NaN         10.5
# 4     3.11    91.0       NaN  104.56            NaN      306.0         11.4
#
#    Stage
# 0    4.0
# 1    1.0
# 2    3.0
# 3    4.0
# 4    2.0

# %%
df['Hepatomegaly'].fillna('N',inplace = True)
df['Spiders'].fillna('N',inplace = True)

# %%
df.head()
# Out:
#      Age Sex Ascites Hepatomegaly Spiders Edema  Bilirubin  Cholesterol  \
# 0  19581   F       N            N       Y     N        0.3        279.0
# 1  22880   F       N            N       N     N        0.3          NaN
# 2  27957   F       N            N       N     N        0.3        328.0
# 3  21111   F       N            Y       Y     N        0.3        302.0
# 4  18061   F       N            N       N     N        0.5        344.0
#
#    Albumin  Copper  Alk_Phos    SGOT  Tryglicerides  Platelets  Prothrombin  \
# 0     2.96    84.0    1500.8   99.43          109.0      293.0         10.2
# 1     2.96     NaN    1835.4   26.35          131.0      308.0         10.8
# 2     2.64     4.0       NaN     NaN          116.0      194.0         10.3
# 3     2.02    49.0       NaN   26.35            NaN        NaN         10.5
# 4     3.11    91.0       NaN  104.56            NaN      306.0         11.4
#
#    Stage
# 0    4.0
# 1    1.0
# 2    3.0
# 3    4.0
# 4    2.0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encode_Sex = LabelEncoder()
encode_As = LabelEncoder()
encode_Hepa = LabelEncoder()
encode_Ed = LabelEncoder()

# %%
df['Sex'] = encode_Sex.fit_transform(df['Sex'])

# %%
df['Ascites'] = encode_As.fit_transform(df['Ascites'])
df['Hepatomegaly'] = encode_Hepa.fit_transform(df['Hepatomegaly'])
df['Edema'] = encode_Ed.fit_transform(df['Edema'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6800 entries, 0 to 6799
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            6800 non-null   int64
#  1   Sex            6800 non-null   int32
#  2   Ascites        6800 non-null   int32
#  3   Hepatomegaly   6800 non-null   int32
#  4   Spiders        6800 non-null   object
#  5   Edema          6800 non-null   int32
#  6   Bilirubin      6800 non-null   float64
#  7   Cholesterol    3699 non-null   float64
#  8   Albumin        6800 non-null   float64
#  9   Copper         4644 non-null   float64
#  10  Alk_Phos       4302 non-null   float64
#  11  SGOT           4698 non-null   float64
#  12  Tryglicerides  3988 non-null   float64
#  13  Platelets      6462 non-null   float64
#  14  Prothrombin    6645 non-null   float64
#  15  Stage          6800 non-null   float64
# dtypes: float64(10), int32(4), int64(1), object(1)
# ...

# %%
df.head(25)
# Out:
#       Age  Sex  Ascites  Hepatomegaly Spiders  Edema  Bilirubin  Cholesterol  \
# 0   19581    0        0             0       Y      0        0.3        279.0
# 1   22880    0        0             0       N      0        0.3          NaN
# 2   27957    0        0             0       N      0        0.3        328.0
# 3   21111    0        0             1       Y      0        0.3        302.0
# 4   18061    0        0             0       N      0        0.5        344.0
# 5   14353    0        1             0       N      0        9.9          NaN
# 6   25357    0        0             1       N      0        0.3          NaN
# 7   28620    0        0             0       N      0        2.0        357.0
# 8   24638    0        0             0       N      0        1.2          NaN
# 9   13860    0        0             0       N      0        8.7          NaN
# 10  28650    0        0             1       N      0        2.5          NaN
# ...

# %%
encode_Sp = LabelEncoder()

# %%
df['Spiders'] = encode_Sp.fit_transform(df['Spiders'])
df.head()
# Out:
#      Age  Sex  Ascites  Hepatomegaly  Spiders  Edema  Bilirubin  Cholesterol  \
# 0  19581    0        0             0        1      0        0.3        279.0
# 1  22880    0        0             0        0      0        0.3          NaN
# 2  27957    0        0             0        0      0        0.3        328.0
# 3  21111    0        0             1        1      0        0.3        302.0
# 4  18061    0        0             0        0      0        0.5        344.0
#
#    Albumin  Copper  Alk_Phos    SGOT  Tryglicerides  Platelets  Prothrombin  \
# 0     2.96    84.0    1500.8   99.43          109.0      293.0         10.2
# 1     2.96     NaN    1835.4   26.35          131.0      308.0         10.8
# 2     2.64     4.0       NaN     NaN          116.0      194.0         10.3
# 3     2.02    49.0       NaN   26.35            NaN        NaN         10.5
# 4     3.11    91.0       NaN  104.56            NaN      306.0         11.4
#
#    Stage
# 0    4.0
# 1    1.0
# 2    3.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6800 entries, 0 to 6799
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            6800 non-null   int64
#  1   Sex            6800 non-null   int32
#  2   Ascites        6800 non-null   int32
#  3   Hepatomegaly   6800 non-null   int32
#  4   Spiders        6800 non-null   int32
#  5   Edema          6800 non-null   int32
#  6   Bilirubin      6800 non-null   float64
#  7   Cholesterol    3699 non-null   float64
#  8   Albumin        6800 non-null   float64
#  9   Copper         4644 non-null   float64
#  10  Alk_Phos       4302 non-null   float64
#  11  SGOT           4698 non-null   float64
#  12  Tryglicerides  3988 non-null   float64
#  13  Platelets      6462 non-null   float64
#  14  Prothrombin    6645 non-null   float64
#  15  Stage          6800 non-null   float64
# dtypes: float64(10), int32(5), int64(1)
# memory usage: 717.3 KB

# %%
Total_Chol = df['Cholesterol'].sum()
print(Total_Chol/3699)
# Out:
# 294.5758313057583

# %%
df['Cholesterol'].fillna(Total_Chol/3699,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6800 entries, 0 to 6799
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            6800 non-null   int64
#  1   Sex            6800 non-null   int32
#  2   Ascites        6800 non-null   int32
#  3   Hepatomegaly   6800 non-null   int32
#  4   Spiders        6800 non-null   int32
#  5   Edema          6800 non-null   int32
#  6   Bilirubin      6800 non-null   float64
#  7   Cholesterol    6800 non-null   float64
#  8   Albumin        6800 non-null   float64
#  9   Copper         4644 non-null   float64
#  10  Alk_Phos       4302 non-null   float64
#  11  SGOT           4698 non-null   float64
#  12  Tryglicerides  3988 non-null   float64
#  13  Platelets      6462 non-null   float64
#  14  Prothrombin    6645 non-null   float64
#  15  Stage          6800 non-null   float64
# dtypes: float64(10), int32(5), int64(1)
# memory usage: 717.3 KB

# %%
totCop = df['Copper'].sum()
meanCop = totCop/4644
meanCop
# Out:
# 68.56912144702842

# %%
df['Copper'].fillna(meanCop,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6800 entries, 0 to 6799
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            6800 non-null   int64
#  1   Sex            6800 non-null   int32
#  2   Ascites        6800 non-null   int32
#  3   Hepatomegaly   6800 non-null   int32
#  4   Spiders        6800 non-null   int32
#  5   Edema          6800 non-null   int32
#  6   Bilirubin      6800 non-null   float64
#  7   Cholesterol    6800 non-null   float64
#  8   Albumin        6800 non-null   float64
#  9   Copper         6800 non-null   float64
#  10  Alk_Phos       4302 non-null   float64
#  11  SGOT           4698 non-null   float64
#  12  Tryglicerides  3988 non-null   float64
#  13  Platelets      6462 non-null   float64
#  14  Prothrombin    6645 non-null   float64
#  15  Stage          6800 non-null   float64
# dtypes: float64(10), int32(5), int64(1)
# memory usage: 717.3 KB

# %%
totAlk_Phos = df['Alk_Phos'].sum()
meanAlk_Phos = totAlk_Phos/4302
df['Alk_Phos'].fillna(meanAlk_Phos,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6800 entries, 0 to 6799
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            6800 non-null   int64
#  1   Sex            6800 non-null   int32
#  2   Ascites        6800 non-null   int32
#  3   Hepatomegaly   6800 non-null   int32
#  4   Spiders        6800 non-null   int32
#  5   Edema          6800 non-null   int32
#  6   Bilirubin      6800 non-null   float64
#  7   Cholesterol    6800 non-null   float64
#  8   Albumin        6800 non-null   float64
#  9   Copper         6800 non-null   float64
#  10  Alk_Phos       6800 non-null   float64
#  11  SGOT           4698 non-null   float64
#  12  Tryglicerides  3988 non-null   float64
#  13  Platelets      6462 non-null   float64
#  14  Prothrombin    6645 non-null   float64
#  15  Stage          6800 non-null   float64
# dtypes: float64(10), int32(5), int64(1)
# memory usage: 717.3 KB

# %%
totSGOT = df['SGOT'].sum()
meanSGOT = totSGOT/4698
df['SGOT'].fillna(meanSGOT,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6800 entries, 0 to 6799
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            6800 non-null   int64
#  1   Sex            6800 non-null   int32
#  2   Ascites        6800 non-null   int32
#  3   Hepatomegaly   6800 non-null   int32
#  4   Spiders        6800 non-null   int32
#  5   Edema          6800 non-null   int32
#  6   Bilirubin      6800 non-null   float64
#  7   Cholesterol    6800 non-null   float64
#  8   Albumin        6800 non-null   float64
#  9   Copper         6800 non-null   float64
#  10  Alk_Phos       6800 non-null   float64
#  11  SGOT           6800 non-null   float64
#  12  Tryglicerides  3988 non-null   float64
#  13  Platelets      6462 non-null   float64
#  14  Prothrombin    6645 non-null   float64
#  15  Stage          6800 non-null   float64
# dtypes: float64(10), int32(5), int64(1)
# memory usage: 717.3 KB

# %%
totTryglicerides = df['Tryglicerides'].sum()
meanTryglicerides = totTryglicerides/3988
df['Tryglicerides'].fillna(meanTryglicerides,inplace = True)

# %%
totPlatelets = df['Platelets'].sum()
meanPlatelets = totPlatelets/6462
df['Platelets'].fillna(meanPlatelets,inplace = True)

# %%
totProthrombin = df['Prothrombin'].sum()
meanProthrombin = totProthrombin/6645
df['Prothrombin'].fillna(meanProthrombin,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6800 entries, 0 to 6799
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            6800 non-null   int64
#  1   Sex            6800 non-null   int32
#  2   Ascites        6800 non-null   int32
#  3   Hepatomegaly   6800 non-null   int32
#  4   Spiders        6800 non-null   int32
#  5   Edema          6800 non-null   int32
#  6   Bilirubin      6800 non-null   float64
#  7   Cholesterol    6800 non-null   float64
#  8   Albumin        6800 non-null   float64
#  9   Copper         6800 non-null   float64
#  10  Alk_Phos       6800 non-null   float64
#  11  SGOT           6800 non-null   float64
#  12  Tryglicerides  6800 non-null   float64
#  13  Platelets      6800 non-null   float64
#  14  Prothrombin    6800 non-null   float64
#  15  Stage          6800 non-null   float64
# dtypes: float64(10), int32(5), int64(1)
# memory usage: 717.3 KB

# %%
df.head(20)
# Out:
#       Age  Sex  Ascites  Hepatomegaly  Spiders  Edema  Bilirubin  Cholesterol  \
# 0   19581    0        0             0        1      0        0.3   279.000000
# 1   22880    0        0             0        0      0        0.3   294.575831
# 2   27957    0        0             0        0      0        0.3   328.000000
# 3   21111    0        0             1        1      0        0.3   302.000000
# 4   18061    0        0             0        0      0        0.5   344.000000
# 5   14353    0        1             0        0      0        9.9   294.575831
# 6   25357    0        0             1        0      0        0.3   294.575831
# 7   28620    0        0             0        0      0        2.0   357.000000
# 8   24638    0        0             0        0      0        1.2   294.575831
# 9   13860    0        0             0        0      0        8.7   294.575831
# 10  28650    0        0             1        0      0        2.5   294.575831
# ...

# %%
encode_Stage = LabelEncoder()
df['Stage'] = encode_Stage.fit_transform(df['Stage'])

# %%
df.head()
# Out:
#      Age  Sex  Ascites  Hepatomegaly  Spiders  Edema  Bilirubin  Cholesterol  \
# 0  19581    0        0             0        1      0        0.3   279.000000
# 1  22880    0        0             0        0      0        0.3   294.575831
# 2  27957    0        0             0        0      0        0.3   328.000000
# 3  21111    0        0             1        1      0        0.3   302.000000
# 4  18061    0        0             0        0      0        0.5   344.000000
#
#    Albumin     Copper     Alk_Phos        SGOT  Tryglicerides   Platelets  \
# 0     2.96  84.000000  1500.800000   99.430000     109.000000  293.000000
# 1     2.96  68.569121  1835.400000   26.350000     131.000000  308.000000
# 2     2.64   4.000000  1802.951464   79.554427     116.000000  194.000000
# 3     2.02  49.000000  1802.951464   26.350000     133.857823  293.306097
# 4     3.11  91.000000  1802.951464  104.560000     133.857823  306.000000
#
#    Prothrombin  Stage
# 0         10.2      3
# ...

# %%
X = df.iloc[:,:-1].values

# %%
y = df.iloc[:,-1].values

# %%
X.shape
# Out:
# (6800, 15)

# %%
y.shape
# Out:
# (6800,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X = scaler.fit_transform(X)

# %%
X
# Out:
# array([[-7.02712385e-01, -4.06671021e-01, -3.05652384e-01, ...,
#         -6.86454671e-01, -2.72718582e-03, -9.28453257e-01],
#        [ 3.59178269e-03, -4.06671021e-01, -3.05652384e-01, ...,
#         -7.89194707e-02,  1.30915950e-01, -3.88147451e-01],
#        [ 1.09055943e+00, -4.06671021e-01, -3.05652384e-01, ...,
#         -4.93148017e-01, -8.84771879e-01, -8.38402289e-01],
#        ...,
#        [ 2.65217637e-01, -4.06671021e-01, -3.05652384e-01, ...,
#         -2.99841362e-01, -1.69554023e+00, -1.73891197e+00],
#        [-6.57752132e-01, -4.06671021e-01, -3.05652384e-01, ...,
#          3.92623847e-03,  5.40754898e-01, -5.68249387e-01],
#        [ 5.09929872e-01, -4.06671021e-01,  3.27169049e+00, ...,
#         -1.79106413e+00, -4.72748976e-02, -1.17994549e-01]])

# %%
# scaler_y = StandardScaler()

# %%
# y = y.reshape(len(y),1)

# %%
# y = scaler_y.fit_transform(y)

# %%
len(y)
# Out:
# 6800

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators = 40)

# %%
from sklearn.model_selection import StratifiedKFold

# %%
skf = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)

# %%
def get_score(model,X_train,X_test,y_train,y_test):
    model.fit(X_train,y_train)
    return model.score(X_test,y_test)

# %%
scores = []

for train_index,test_index in skf.split(X,y):
    X_train,X_test,y_train,y_test = X[train_index],X[test_index],y[train_index],y[test_index]
    scores.append(get_score(forest,X_train,X_test,y_train,y_test))

# %%
# from sklearn.model_selection import cross_val_score

# %%
np.mean(scores)
# Out:
# 0.4882352941176471

# %%
# pip install xgboost

# %%
from xgboost import XGBClassifier
# model = XGBClassifier(learning_rate=0.2, max_depth=8, random_state=1, gamma=0, eval_metric='error')
model = XGBClassifier()

# %%
skf_xg = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)

# %%
acc=[]
def training(train, test, fold_no):
  X_train = train
  y_train = y[train_index]
  X_test = test
  y_test = y[test_index]
  model.fit(X_train, y_train)
  score = model.score(X_test,y_test)
  acc.append(score)
  print('For Fold {} the accuracy is {}'.format(str(fold_no),score))

fold_no = 1
for train_index,test_index in skf.split(X, y):
  train = X[train_index,:]
  test = X[test_index,:]
  training(train, test, fold_no)
  fold_no += 1
print()
print('XGboost model Mean Accuracy = ', np.mean(acc))
# Out:
# For Fold 1 the accuracy is 0.48676470588235293
# For Fold 2 the accuracy is 0.4838235294117647
# For Fold 3 the accuracy is 0.4661764705882353
# For Fold 4 the accuracy is 0.4970588235294118
# For Fold 5 the accuracy is 0.4588235294117647
# For Fold 6 the accuracy is 0.4676470588235294
# For Fold 7 the accuracy is 0.4838235294117647
# For Fold 8 the accuracy is 0.49558823529411766
# For Fold 9 the accuracy is 0.45294117647058824
# For Fold 10 the accuracy is 0.48676470588235293
#
# XGboost model Mean Accuracy =  0.4779411764705882

# %%
print(np.mean(acc))
# Out:
# 0.4779411764705882
